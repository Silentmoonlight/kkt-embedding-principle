# %%
import torch
import torch.nn as nn
import math
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset

# --- Part 1: Original Toy CNN Experiment (for reference, not run by default) ---
# ... (Code from Part 1 is unchanged and omitted for brevity) ...


# --- Part 2: Final MNIST Experiment (Homogeneous Models Only) ---

# --- 2.1. MNIST Experiment Settings ---
MNIST_LEARNING_RATE = 0.001 
MNIST_BATCH_SIZE = 64
MNIST_EPOCHS = 1000

# --- 2.2. MNIST Data Loading and Preprocessing ---
def get_mnist_binary_loaders(batch_size=64):
    """
    Loads MNIST and creates a binary classification task (3 vs 5).
    """
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])
    # Use the full training dataset for evaluation
    train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    
    idx = (train_dataset.targets == 3) | (train_dataset.targets == 5)
    train_dataset.data = train_dataset.data[idx]
    train_dataset.targets = train_dataset.targets[idx]
    
    train_dataset.targets[train_dataset.targets == 3] = -1
    train_dataset.targets[train_dataset.targets == 5] = 1
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    # Create a separate loader for evaluation without shuffling
    eval_loader = DataLoader(train_dataset, batch_size=512, shuffle=False)
    return train_loader, eval_loader

# --- 2.3. MNIST Model Definitions (Homogeneous Only) ---
def leaky_relu(x, negative_slope=0.01):
    return torch.where(x > 0, x, x * negative_slope)

# MLP Models
class SmallMLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28*28, 128, bias=False)
        self.fc2 = nn.Linear(128, 1, bias=False)
    def forward(self, x):
        x = x.view(-1, 28*28)
        x = leaky_relu(self.fc1(x))
        x = self.fc2(x)
        return x

class LargeMLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28*28, 256, bias=False)
        self.fc2 = nn.Linear(256, 1, bias=False)
    def forward(self, x):
        x = x.view(-1, 28*28)
        x = leaky_relu(self.fc1(x))
        x = self.fc2(x)
        return x

# CNN Models
class SmallMNISTCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5, bias=False)
        self.pool = nn.AvgPool2d(2) 
        self.fc1 = nn.Linear(10 * 12 * 12, 1, bias=False)
    def forward(self, x):
        x = leaky_relu(self.conv1(x))
        x = self.pool(x)
        x = x.view(-1, 10 * 12 * 12)
        x = self.fc1(x)
        return x

class LargeMNISTCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 20, kernel_size=5, bias=False)
        self.pool = nn.AvgPool2d(2)
        self.fc1 = nn.Linear(20 * 12 * 12, 1, bias=False)
    def forward(self, x):
        x = leaky_relu(self.conv1(x))
        x = self.pool(x)
        x = x.view(-1, 20 * 12 * 12)
        x = self.fc1(x)
        return x

# --- 2.4. Transformation Functions (Homogeneous Only) ---
def transform_mlp_params(small_model):
    params = dict(small_model.named_parameters())
    W1_s, W2_s = params['fc1.weight'], params['fc2.weight']
    c = 1.0 / np.sqrt(2)
    W1_l = torch.cat([c * W1_s, c * W1_s], dim=0)
    W2_l = torch.cat([c * W2_s, c * W2_s], dim=1)
    return {'fc1.weight': W1_l, 'fc2.weight': W2_l}

def transform_cnn_mnist_params(small_model):
    params = dict(small_model.named_parameters())
    W_conv_s, W_fc_s = params['conv1.weight'], params['fc1.weight']
    c = 1.0 / np.sqrt(2)
    W_conv_l = torch.cat([c * W_conv_s, c * W_conv_s], dim=0)
    W_fc_l = torch.cat([c * W_fc_s, c * W_fc_s], dim=1)
    return {'conv1.weight': W_conv_l, 'fc1.weight': W_fc_l}

def exponential_loss(y_pred, y_true):
    return torch.mean(torch.exp(-y_true * y_pred))

# --- 2.5. New: Accuracy and Loss Calculation ---
def calculate_metrics(model, loader):
    model.eval() # Set model to evaluation mode
    total_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for data, target in loader:
            data, target = data.to(torch.double), target.to(torch.double).view(-1, 1)
            output = model(data)
            
            # Calculate loss
            loss = exponential_loss(output, target)
            total_loss += loss.item() * data.size(0)
            
            # Calculate accuracy
            predicted = torch.sign(output)
            correct += (predicted == target).sum().item()
            total += target.size(0)
            
    avg_loss = total_loss / total
    accuracy = 100 * correct / total
    model.train() # Set model back to training mode
    return avg_loss, accuracy

# --- 2.6. MNIST Training and Evaluation Loop ---
def run_mnist_experiment(model_type='mlp'):
    print(f"\n--- Running MNIST Experiment: Homogeneous {model_type.upper()} ---")
    
    train_loader, eval_loader = get_mnist_binary_loaders(MNIST_BATCH_SIZE)
    
    if model_type == 'mlp':
        small_net = SmallMLP()
        large_net = LargeMLP()
        transform_fn = transform_mlp_params
    else: # cnn
        small_net = SmallMNISTCNN()
        large_net = LargeMNISTCNN()
        transform_fn = transform_cnn_mnist_params

    small_net.to(torch.double)
    large_net.to(torch.double)

    with torch.no_grad():
        for param in small_net.parameters():
            if param.dim() > 1:
                nn.init.kaiming_normal_(param, a=math.sqrt(5))
            else:
                nn.init.zeros_(param)
            
        initial_large_params = transform_fn(small_net)
        for name, param in large_net.named_parameters():
            param.data.copy_(initial_large_params[name])

    optimizer_small = torch.optim.SGD(small_net.parameters(), lr=MNIST_LEARNING_RATE)
    optimizer_large = torch.optim.SGD(large_net.parameters(), lr=MNIST_LEARNING_RATE)
    
    error_history = []
    
    for epoch in range(MNIST_EPOCHS):
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(torch.double), target.to(torch.double).view(-1, 1)
            
            optimizer_small.zero_grad()
            output_small = small_net(data)
            loss_small = exponential_loss(output_small, target)
            loss_small.backward()
            optimizer_small.step()
            
            optimizer_large.zero_grad()
            output_large = large_net(data)
            loss_large = exponential_loss(output_large, target)
            loss_large.backward()
            optimizer_large.step()
            
            with torch.no_grad():
                predicted_params_large = transform_fn(small_net)
                actual_vec_list = []
                predicted_vec_list = []
                for name, param in sorted(large_net.named_parameters()):
                    actual_vec_list.append(param.flatten())
                    predicted_vec_list.append(predicted_params_large[name].flatten())
                actual_vec = torch.cat(actual_vec_list)
                predicted_vec = torch.cat(predicted_vec_list)
                error = torch.norm(actual_vec - predicted_vec).item()
                error_history.append(error)

        # --- New: Print Loss and Accuracy at the end of each epoch ---
        avg_loss, accuracy = calculate_metrics(small_net, eval_loader)
        print(f"Epoch {epoch+1}/{MNIST_EPOCHS} | Avg Loss: {avg_loss:.4f} | Accuracy: {accuracy:.2f}% | Final Batch Error: {error:.4e}")
        
    print(f"Result: Max Trajectory Error = {max(error_history):.4e}")
    print("--------------------------------------------------")
    return max(error_history)


if __name__ == '__main__':
    results = {}
    results['mlp_no_bias'] = run_mnist_experiment(model_type='mlp')
    results['cnn_no_bias'] = run_mnist_experiment(model_type='cnn')
    
    print("\n========= MNIST Experiment Summary =========")
    for key, value in results.items():
        print(f"{key:<15}: Max Trajectory Error = {value:.4e}")
    print("==========================================")
# Out:
# --- Running MNIST Experiment: Homogeneous MLP ---
# Epoch 1/1000 | Avg Loss: 0.7281 | Accuracy: 87.79% | Final Batch Error: 5.9833e-15
# Epoch 254/1000 | Avg Loss: 0.0403 | Accuracy: 99.37% | Final Batch Error: 1.0043e-13
# Epoch 255/1000 | Avg Loss: 0.0401 | Accuracy: 99.38% | Final Batch Error: 1.0057e-13
# Epoch 256/1000 | Avg Loss: 0.0400 | Accuracy: 99.35% | Final Batch Error: 1.0095e-13
# Epoch 257/1000 | Avg Loss: 0.0400 | Accuracy: 99.36% | Final Batch Error: 1.0125e-13
# Epoch 258/1000 | Avg Loss: 0.0398 | Accuracy: 99.39% | Final Batch Error: 1.0171e-13
# Epoch 259/1000 | Avg Loss: 0.0393 | Accuracy: 99.39% | Final Batch Error: 1.0203e-13
# Epoch 260/1000 | Avg Loss: 0.0391 | Accuracy: 99.39% | Final Batch Error: 1.0203e-13
# Epoch 261/1000 | Avg Loss: 0.0390 | Accuracy: 99.41% | Final Batch Error: 1.0223e-13
# Epoch 262/1000 | Avg Loss: 0.0390 | Accuracy: 99.37% | Final Batch Error: 1.0241e-13
# Epoch 263/1000 | Avg Loss: 0.0388 | Accuracy: 99.39% | Final Batch Error: 1.0288e-13
# Epoch 264/1000 | Avg Loss: 0.0385 | Accuracy: 99.40% | Final Batch Error: 1.0308e-13
# Epoch 265/1000 | Avg Loss: 0.0385 | Accuracy: 99.38% | Final Batch Error: 1.0298e-13
# Epoch 266/1000 | Avg Loss: 0.0392 | Accuracy: 99.35% | Final Batch Error: 1.0340e-13
# Epoch 267/1000 | Avg Loss: 0.0379 | Accuracy: 99.42% | Final Batch Error: 1.0372e-13
# Epoch 268/1000 | Avg Loss: 0.0380 | Accuracy: 99.41% | Final Batch Error: 1.0403e-13
# Epoch 269/1000 | Avg Loss: 0.0378 | Accuracy: 99.42% | Final Batch Error: 1.0408e-13
# Epoch 270/1000 | Avg Loss: 0.0387 | Accuracy: 99.42% | Final Batch Error: 1.0459e-13
# Epoch 271/1000 | Avg Loss: 0.0373 | Accuracy: 99.42% | Final Batch Error: 1.0479e-13
# Epoch 272/1000 | Avg Loss: 0.0371 | Accuracy: 99.43% | Final Batch Error: 1.0501e-13
# Epoch 273/1000 | Avg Loss: 0.0370 | Accuracy: 99.44% | Final Batch Error: 1.0527e-13
# Epoch 274/1000 | Avg Loss: 0.0370 | Accuracy: 99.44% | Final Batch Error: 1.0549e-13
# Epoch 275/1000 | Avg Loss: 0.0368 | Accuracy: 99.44% | Final Batch Error: 1.0549e-13
# Epoch 276/1000 | Avg Loss: 0.0365 | Accuracy: 99.45% | Final Batch Error: 1.0575e-13
# Epoch 277/1000 | Avg Loss: 0.0363 | Accuracy: 99.45% | Final Batch Error: 1.0606e-13
# Epoch 278/1000 | Avg Loss: 0.0362 | Accuracy: 99.48% | Final Batch Error: 1.0624e-13
# Epoch 279/1000 | Avg Loss: 0.0369 | Accuracy: 99.51% | Final Batch Error: 1.0624e-13
# Epoch 280/1000 | Avg Loss: 0.0368 | Accuracy: 99.41% | Final Batch Error: 1.0624e-13
# Epoch 281/1000 | Avg Loss: 0.0358 | Accuracy: 99.52% | Final Batch Error: 1.0638e-13
# Epoch 282/1000 | Avg Loss: 0.0357 | Accuracy: 99.52% | Final Batch Error: 1.0634e-13
# Epoch 283/1000 | Avg Loss: 0.0356 | Accuracy: 99.52% | Final Batch Error: 1.0641e-13
# Epoch 284/1000 | Avg Loss: 0.0354 | Accuracy: 99.53% | Final Batch Error: 1.0670e-13
# Epoch 285/1000 | Avg Loss: 0.0351 | Accuracy: 99.52% | Final Batch Error: 1.0685e-13
# Epoch 286/1000 | Avg Loss: 0.0350 | Accuracy: 99.48% | Final Batch Error: 1.0718e-13
# Epoch 287/1000 | Avg Loss: 0.0348 | Accuracy: 99.52% | Final Batch Error: 1.0731e-13
# Epoch 288/1000 | Avg Loss: 0.0347 | Accuracy: 99.54% | Final Batch Error: 1.0754e-13
# Epoch 289/1000 | Avg Loss: 0.0347 | Accuracy: 99.55% | Final Batch Error: 1.0759e-13
# Epoch 290/1000 | Avg Loss: 0.0345 | Accuracy: 99.50% | Final Batch Error: 1.0797e-13
# Epoch 291/1000 | Avg Loss: 0.0344 | Accuracy: 99.48% | Final Batch Error: 1.0810e-13
# Epoch 292/1000 | Avg Loss: 0.0342 | Accuracy: 99.48% | Final Batch Error: 1.0855e-13
# Epoch 293/1000 | Avg Loss: 0.0340 | Accuracy: 99.52% | Final Batch Error: 1.0884e-13
# Epoch 294/1000 | Avg Loss: 0.0339 | Accuracy: 99.56% | Final Batch Error: 1.0905e-13
# Epoch 295/1000 | Avg Loss: 0.0337 | Accuracy: 99.53% | Final Batch Error: 1.0947e-13
# Epoch 296/1000 | Avg Loss: 0.0336 | Accuracy: 99.58% | Final Batch Error: 1.0975e-13
# Epoch 297/1000 | Avg Loss: 0.0335 | Accuracy: 99.54% | Final Batch Error: 1.0991e-13
# Epoch 298/1000 | Avg Loss: 0.0335 | Accuracy: 99.51% | Final Batch Error: 1.0999e-13
# Epoch 299/1000 | Avg Loss: 0.0333 | Accuracy: 99.52% | Final Batch Error: 1.0996e-13
# Epoch 300/1000 | Avg Loss: 0.0331 | Accuracy: 99.58% | Final Batch Error: 1.1004e-13
# Epoch 301/1000 | Avg Loss: 0.0331 | Accuracy: 99.52% | Final Batch Error: 1.1019e-13
# Epoch 302/1000 | Avg Loss: 0.0330 | Accuracy: 99.52% | Final Batch Error: 1.1032e-13
# Epoch 303/1000 | Avg Loss: 0.0327 | Accuracy: 99.54% | Final Batch Error: 1.1017e-13
# Epoch 304/1000 | Avg Loss: 0.0326 | Accuracy: 99.55% | Final Batch Error: 1.1021e-13
# Epoch 305/1000 | Avg Loss: 0.0331 | Accuracy: 99.51% | Final Batch Error: 1.1036e-13
# Epoch 306/1000 | Avg Loss: 0.0324 | Accuracy: 99.55% | Final Batch Error: 1.1027e-13
# Epoch 307/1000 | Avg Loss: 0.0328 | Accuracy: 99.51% | Final Batch Error: 1.1063e-13
# Epoch 308/1000 | Avg Loss: 0.0321 | Accuracy: 99.61% | Final Batch Error: 1.1080e-13
# Epoch 309/1000 | Avg Loss: 0.0320 | Accuracy: 99.61% | Final Batch Error: 1.1104e-13
# Epoch 310/1000 | Avg Loss: 0.0319 | Accuracy: 99.58% | Final Batch Error: 1.1132e-13
# Epoch 311/1000 | Avg Loss: 0.0320 | Accuracy: 99.64% | Final Batch Error: 1.1145e-13
# Epoch 312/1000 | Avg Loss: 0.0316 | Accuracy: 99.61% | Final Batch Error: 1.1180e-13
# Epoch 313/1000 | Avg Loss: 0.0317 | Accuracy: 99.66% | Final Batch Error: 1.1209e-13
# Epoch 314/1000 | Avg Loss: 0.0314 | Accuracy: 99.64% | Final Batch Error: 1.1235e-13
# Epoch 315/1000 | Avg Loss: 0.0314 | Accuracy: 99.56% | Final Batch Error: 1.1248e-13
# Epoch 316/1000 | Avg Loss: 0.0311 | Accuracy: 99.58% | Final Batch Error: 1.1288e-13
# Epoch 317/1000 | Avg Loss: 0.0310 | Accuracy: 99.63% | Final Batch Error: 1.1322e-13
# Epoch 318/1000 | Avg Loss: 0.0309 | Accuracy: 99.63% | Final Batch Error: 1.1329e-13
# Epoch 319/1000 | Avg Loss: 0.0309 | Accuracy: 99.58% | Final Batch Error: 1.1355e-13
# Epoch 320/1000 | Avg Loss: 0.0307 | Accuracy: 99.58% | Final Batch Error: 1.1357e-13
# Epoch 321/1000 | Avg Loss: 0.0307 | Accuracy: 99.68% | Final Batch Error: 1.1387e-13
# Epoch 322/1000 | Avg Loss: 0.0308 | Accuracy: 99.57% | Final Batch Error: 1.1427e-13
# Epoch 323/1000 | Avg Loss: 0.0303 | Accuracy: 99.65% | Final Batch Error: 1.1441e-13
# Epoch 324/1000 | Avg Loss: 0.0303 | Accuracy: 99.59% | Final Batch Error: 1.1472e-13
# Epoch 325/1000 | Avg Loss: 0.0301 | Accuracy: 99.66% | Final Batch Error: 1.1482e-13
# Epoch 326/1000 | Avg Loss: 0.0302 | Accuracy: 99.58% | Final Batch Error: 1.1498e-13
# Epoch 327/1000 | Avg Loss: 0.0300 | Accuracy: 99.69% | Final Batch Error: 1.1517e-13
# Epoch 328/1000 | Avg Loss: 0.0297 | Accuracy: 99.65% | Final Batch Error: 1.1553e-13
# Epoch 329/1000 | Avg Loss: 0.0297 | Accuracy: 99.62% | Final Batch Error: 1.1546e-13
# Epoch 330/1000 | Avg Loss: 0.0297 | Accuracy: 99.68% | Final Batch Error: 1.1578e-13
# Epoch 331/1000 | Avg Loss: 0.0295 | Accuracy: 99.60% | Final Batch Error: 1.1586e-13
# Epoch 332/1000 | Avg Loss: 0.0294 | Accuracy: 99.61% | Final Batch Error: 1.1624e-13
# Epoch 333/1000 | Avg Loss: 0.0293 | Accuracy: 99.61% | Final Batch Error: 1.1636e-13
# Epoch 334/1000 | Avg Loss: 0.0291 | Accuracy: 99.64% | Final Batch Error: 1.1651e-13
# Epoch 335/1000 | Avg Loss: 0.0291 | Accuracy: 99.62% | Final Batch Error: 1.1660e-13
# Epoch 336/1000 | Avg Loss: 0.0289 | Accuracy: 99.65% | Final Batch Error: 1.1692e-13
# Epoch 337/1000 | Avg Loss: 0.0288 | Accuracy: 99.64% | Final Batch Error: 1.1714e-13
# Epoch 338/1000 | Avg Loss: 0.0287 | Accuracy: 99.67% | Final Batch Error: 1.1738e-13
# Epoch 339/1000 | Avg Loss: 0.0286 | Accuracy: 99.65% | Final Batch Error: 1.1771e-13
# Epoch 340/1000 | Avg Loss: 0.0289 | Accuracy: 99.70% | Final Batch Error: 1.1781e-13
# Epoch 341/1000 | Avg Loss: 0.0284 | Accuracy: 99.67% | Final Batch Error: 1.1800e-13
# Epoch 342/1000 | Avg Loss: 0.0289 | Accuracy: 99.70% | Final Batch Error: 1.1795e-13
# Epoch 343/1000 | Avg Loss: 0.0282 | Accuracy: 99.71% | Final Batch Error: 1.1817e-13
# Epoch 344/1000 | Avg Loss: 0.0281 | Accuracy: 99.71% | Final Batch Error: 1.1865e-13
# Epoch 345/1000 | Avg Loss: 0.0280 | Accuracy: 99.68% | Final Batch Error: 1.1874e-13
# Epoch 346/1000 | Avg Loss: 0.0279 | Accuracy: 99.71% | Final Batch Error: 1.1882e-13
# Epoch 347/1000 | Avg Loss: 0.0278 | Accuracy: 99.67% | Final Batch Error: 1.1926e-13
# Epoch 348/1000 | Avg Loss: 0.0277 | Accuracy: 99.68% | Final Batch Error: 1.1941e-13
# Epoch 349/1000 | Avg Loss: 0.0277 | Accuracy: 99.66% | Final Batch Error: 1.1978e-13
# Epoch 350/1000 | Avg Loss: 0.0277 | Accuracy: 99.71% | Final Batch Error: 1.2020e-13
# Epoch 351/1000 | Avg Loss: 0.0278 | Accuracy: 99.72% | Final Batch Error: 1.2040e-13
# Epoch 352/1000 | Avg Loss: 0.0274 | Accuracy: 99.70% | Final Batch Error: 1.2062e-13
# Epoch 353/1000 | Avg Loss: 0.0276 | Accuracy: 99.65% | Final Batch Error: 1.2111e-13
# Epoch 354/1000 | Avg Loss: 0.0275 | Accuracy: 99.64% | Final Batch Error: 1.2179e-13
# Epoch 355/1000 | Avg Loss: 0.0270 | Accuracy: 99.73% | Final Batch Error: 1.2184e-13
# Epoch 356/1000 | Avg Loss: 0.0270 | Accuracy: 99.73% | Final Batch Error: 1.2182e-13
# Epoch 357/1000 | Avg Loss: 0.0270 | Accuracy: 99.72% | Final Batch Error: 1.2191e-13
# Epoch 358/1000 | Avg Loss: 0.0268 | Accuracy: 99.70% | Final Batch Error: 1.2188e-13
# Epoch 359/1000 | Avg Loss: 0.0267 | Accuracy: 99.72% | Final Batch Error: 1.2221e-13
# Epoch 360/1000 | Avg Loss: 0.0266 | Accuracy: 99.74% | Final Batch Error: 1.2251e-13
# Epoch 361/1000 | Avg Loss: 0.0265 | Accuracy: 99.73% | Final Batch Error: 1.2276e-13
# Epoch 362/1000 | Avg Loss: 0.0264 | Accuracy: 99.72% | Final Batch Error: 1.2308e-13
# Epoch 363/1000 | Avg Loss: 0.0264 | Accuracy: 99.72% | Final Batch Error: 1.2336e-13
# Epoch 364/1000 | Avg Loss: 0.0263 | Accuracy: 99.72% | Final Batch Error: 1.2361e-13
# Epoch 365/1000 | Avg Loss: 0.0262 | Accuracy: 99.74% | Final Batch Error: 1.2358e-13
# Epoch 366/1000 | Avg Loss: 0.0262 | Accuracy: 99.72% | Final Batch Error: 1.2368e-13
# Epoch 367/1000 | Avg Loss: 0.0266 | Accuracy: 99.63% | Final Batch Error: 1.2361e-13
# Epoch 368/1000 | Avg Loss: 0.0261 | Accuracy: 99.70% | Final Batch Error: 1.2379e-13
# Epoch 369/1000 | Avg Loss: 0.0259 | Accuracy: 99.73% | Final Batch Error: 1.2406e-13
# Epoch 370/1000 | Avg Loss: 0.0259 | Accuracy: 99.75% | Final Batch Error: 1.2436e-13
# Epoch 371/1000 | Avg Loss: 0.0256 | Accuracy: 99.74% | Final Batch Error: 1.2446e-13
# Epoch 372/1000 | Avg Loss: 0.0256 | Accuracy: 99.77% | Final Batch Error: 1.2461e-13
# Epoch 373/1000 | Avg Loss: 0.0259 | Accuracy: 99.76% | Final Batch Error: 1.2478e-13
# Epoch 374/1000 | Avg Loss: 0.0254 | Accuracy: 99.76% | Final Batch Error: 1.2515e-13
# Epoch 375/1000 | Avg Loss: 0.0261 | Accuracy: 99.64% | Final Batch Error: 1.2523e-13
# Epoch 376/1000 | Avg Loss: 0.0252 | Accuracy: 99.75% | Final Batch Error: 1.2544e-13
# Epoch 377/1000 | Avg Loss: 0.0253 | Accuracy: 99.73% | Final Batch Error: 1.2567e-13
# Epoch 378/1000 | Avg Loss: 0.0255 | Accuracy: 99.66% | Final Batch Error: 1.2603e-13
# Epoch 379/1000 | Avg Loss: 0.0251 | Accuracy: 99.76% | Final Batch Error: 1.2597e-13
# Epoch 380/1000 | Avg Loss: 0.0250 | Accuracy: 99.74% | Final Batch Error: 1.2614e-13
# Epoch 381/1000 | Avg Loss: 0.0248 | Accuracy: 99.77% | Final Batch Error: 1.2632e-13
# Epoch 382/1000 | Avg Loss: 0.0250 | Accuracy: 99.77% | Final Batch Error: 1.2634e-13
# Epoch 383/1000 | Avg Loss: 0.0248 | Accuracy: 99.74% | Final Batch Error: 1.2646e-13
# Epoch 384/1000 | Avg Loss: 0.0246 | Accuracy: 99.77% | Final Batch Error: 1.2653e-13
# Epoch 385/1000 | Avg Loss: 0.0245 | Accuracy: 99.77% | Final Batch Error: 1.2669e-13
# Epoch 386/1000 | Avg Loss: 0.0245 | Accuracy: 99.77% | Final Batch Error: 1.2693e-13
# Epoch 387/1000 | Avg Loss: 0.0244 | Accuracy: 99.77% | Final Batch Error: 1.2693e-13
# Epoch 388/1000 | Avg Loss: 0.0243 | Accuracy: 99.77% | Final Batch Error: 1.2712e-13
# Epoch 389/1000 | Avg Loss: 0.0244 | Accuracy: 99.76% | Final Batch Error: 1.2707e-13
# Epoch 390/1000 | Avg Loss: 0.0243 | Accuracy: 99.79% | Final Batch Error: 1.2735e-13
# Epoch 391/1000 | Avg Loss: 0.0242 | Accuracy: 99.79% | Final Batch Error: 1.2764e-13
# Epoch 392/1000 | Avg Loss: 0.0240 | Accuracy: 99.77% | Final Batch Error: 1.2792e-13
# Epoch 393/1000 | Avg Loss: 0.0241 | Accuracy: 99.80% | Final Batch Error: 1.2787e-13
# Epoch 394/1000 | Avg Loss: 0.0241 | Accuracy: 99.79% | Final Batch Error: 1.2796e-13
# Epoch 395/1000 | Avg Loss: 0.0241 | Accuracy: 99.78% | Final Batch Error: 1.2813e-13
# Epoch 396/1000 | Avg Loss: 0.0238 | Accuracy: 99.81% | Final Batch Error: 1.2818e-13
# Epoch 397/1000 | Avg Loss: 0.0236 | Accuracy: 99.78% | Final Batch Error: 1.2853e-13
# Epoch 398/1000 | Avg Loss: 0.0237 | Accuracy: 99.82% | Final Batch Error: 1.2862e-13
# Epoch 399/1000 | Avg Loss: 0.0237 | Accuracy: 99.75% | Final Batch Error: 1.2879e-13
# Epoch 400/1000 | Avg Loss: 0.0236 | Accuracy: 99.79% | Final Batch Error: 1.2908e-13
# Epoch 401/1000 | Avg Loss: 0.0236 | Accuracy: 99.75% | Final Batch Error: 1.2931e-13
# Epoch 402/1000 | Avg Loss: 0.0233 | Accuracy: 99.80% | Final Batch Error: 1.2946e-13
# Epoch 403/1000 | Avg Loss: 0.0235 | Accuracy: 99.79% | Final Batch Error: 1.2950e-13
# Epoch 404/1000 | Avg Loss: 0.0232 | Accuracy: 99.77% | Final Batch Error: 1.2945e-13
# Epoch 405/1000 | Avg Loss: 0.0231 | Accuracy: 99.77% | Final Batch Error: 1.2988e-13
# Epoch 406/1000 | Avg Loss: 0.0235 | Accuracy: 99.72% | Final Batch Error: 1.2981e-13
# Epoch 407/1000 | Avg Loss: 0.0229 | Accuracy: 99.80% | Final Batch Error: 1.2987e-13
# Epoch 408/1000 | Avg Loss: 0.0229 | Accuracy: 99.81% | Final Batch Error: 1.3019e-13
# Epoch 409/1000 | Avg Loss: 0.0228 | Accuracy: 99.78% | Final Batch Error: 1.3026e-13
# Epoch 410/1000 | Avg Loss: 0.0228 | Accuracy: 99.83% | Final Batch Error: 1.3038e-13
# Epoch 411/1000 | Avg Loss: 0.0227 | Accuracy: 99.83% | Final Batch Error: 1.3005e-13
# Epoch 412/1000 | Avg Loss: 0.0229 | Accuracy: 99.76% | Final Batch Error: 1.3039e-13
# Epoch 413/1000 | Avg Loss: 0.0227 | Accuracy: 99.77% | Final Batch Error: 1.3066e-13
# Epoch 414/1000 | Avg Loss: 0.0225 | Accuracy: 99.82% | Final Batch Error: 1.3091e-13
# Epoch 415/1000 | Avg Loss: 0.0227 | Accuracy: 99.81% | Final Batch Error: 1.3117e-13
# Epoch 416/1000 | Avg Loss: 0.0223 | Accuracy: 99.84% | Final Batch Error: 1.3115e-13
# Epoch 417/1000 | Avg Loss: 0.0223 | Accuracy: 99.84% | Final Batch Error: 1.3161e-13
# Epoch 418/1000 | Avg Loss: 0.0222 | Accuracy: 99.80% | Final Batch Error: 1.3173e-13
# Epoch 419/1000 | Avg Loss: 0.0223 | Accuracy: 99.82% | Final Batch Error: 1.3198e-13
# Epoch 420/1000 | Avg Loss: 0.0229 | Accuracy: 99.77% | Final Batch Error: 1.3210e-13
# Epoch 421/1000 | Avg Loss: 0.0221 | Accuracy: 99.77% | Final Batch Error: 1.3239e-13
# Epoch 422/1000 | Avg Loss: 0.0220 | Accuracy: 99.79% | Final Batch Error: 1.3235e-13
# Epoch 423/1000 | Avg Loss: 0.0221 | Accuracy: 99.82% | Final Batch Error: 1.3266e-13
# Epoch 424/1000 | Avg Loss: 0.0220 | Accuracy: 99.82% | Final Batch Error: 1.3289e-13
# Epoch 425/1000 | Avg Loss: 0.0218 | Accuracy: 99.84% | Final Batch Error: 1.3290e-13
# Epoch 426/1000 | Avg Loss: 0.0217 | Accuracy: 99.84% | Final Batch Error: 1.3296e-13
# Epoch 427/1000 | Avg Loss: 0.0216 | Accuracy: 99.83% | Final Batch Error: 1.3299e-13
# Epoch 428/1000 | Avg Loss: 0.0216 | Accuracy: 99.84% | Final Batch Error: 1.3316e-13
# Epoch 429/1000 | Avg Loss: 0.0215 | Accuracy: 99.84% | Final Batch Error: 1.3331e-13
# Epoch 430/1000 | Avg Loss: 0.0215 | Accuracy: 99.84% | Final Batch Error: 1.3344e-13
# Epoch 431/1000 | Avg Loss: 0.0214 | Accuracy: 99.84% | Final Batch Error: 1.3336e-13
# Epoch 432/1000 | Avg Loss: 0.0214 | Accuracy: 99.83% | Final Batch Error: 1.3355e-13
# Epoch 433/1000 | Avg Loss: 0.0215 | Accuracy: 99.78% | Final Batch Error: 1.3369e-13
# Epoch 434/1000 | Avg Loss: 0.0213 | Accuracy: 99.83% | Final Batch Error: 1.3379e-13
# Epoch 435/1000 | Avg Loss: 0.0212 | Accuracy: 99.83% | Final Batch Error: 1.3394e-13
# Epoch 436/1000 | Avg Loss: 0.0212 | Accuracy: 99.84% | Final Batch Error: 1.3399e-13
# Epoch 437/1000 | Avg Loss: 0.0210 | Accuracy: 99.83% | Final Batch Error: 1.3390e-13
# Epoch 438/1000 | Avg Loss: 0.0211 | Accuracy: 99.84% | Final Batch Error: 1.3427e-13
# Epoch 439/1000 | Avg Loss: 0.0209 | Accuracy: 99.84% | Final Batch Error: 1.3424e-13
# Epoch 440/1000 | Avg Loss: 0.0209 | Accuracy: 99.84% | Final Batch Error: 1.3445e-13
# Epoch 441/1000 | Avg Loss: 0.0208 | Accuracy: 99.84% | Final Batch Error: 1.3460e-13
# Epoch 442/1000 | Avg Loss: 0.0208 | Accuracy: 99.82% | Final Batch Error: 1.3472e-13
# Epoch 443/1000 | Avg Loss: 0.0207 | Accuracy: 99.84% | Final Batch Error: 1.3497e-13
# Epoch 444/1000 | Avg Loss: 0.0207 | Accuracy: 99.83% | Final Batch Error: 1.3512e-13
# Epoch 445/1000 | Avg Loss: 0.0206 | Accuracy: 99.82% | Final Batch Error: 1.3563e-13
# Epoch 446/1000 | Avg Loss: 0.0205 | Accuracy: 99.84% | Final Batch Error: 1.3562e-13
# Epoch 447/1000 | Avg Loss: 0.0205 | Accuracy: 99.84% | Final Batch Error: 1.3557e-13
# Epoch 448/1000 | Avg Loss: 0.0204 | Accuracy: 99.84% | Final Batch Error: 1.3588e-13
# Epoch 449/1000 | Avg Loss: 0.0203 | Accuracy: 99.84% | Final Batch Error: 1.3598e-13
# Epoch 450/1000 | Avg Loss: 0.0204 | Accuracy: 99.84% | Final Batch Error: 1.3610e-13
# Epoch 451/1000 | Avg Loss: 0.0205 | Accuracy: 99.84% | Final Batch Error: 1.3628e-13
# Epoch 452/1000 | Avg Loss: 0.0202 | Accuracy: 99.83% | Final Batch Error: 1.3628e-13
# Epoch 453/1000 | Avg Loss: 0.0204 | Accuracy: 99.81% | Final Batch Error: 1.3666e-13
# Epoch 454/1000 | Avg Loss: 0.0201 | Accuracy: 99.84% | Final Batch Error: 1.3688e-13
# Epoch 455/1000 | Avg Loss: 0.0200 | Accuracy: 99.84% | Final Batch Error: 1.3697e-13
# Epoch 456/1000 | Avg Loss: 0.0200 | Accuracy: 99.84% | Final Batch Error: 1.3720e-13
# Epoch 457/1000 | Avg Loss: 0.0199 | Accuracy: 99.84% | Final Batch Error: 1.3740e-13
# Epoch 458/1000 | Avg Loss: 0.0199 | Accuracy: 99.84% | Final Batch Error: 1.3747e-13
# Epoch 459/1000 | Avg Loss: 0.0199 | Accuracy: 99.84% | Final Batch Error: 1.3766e-13
# Epoch 460/1000 | Avg Loss: 0.0198 | Accuracy: 99.84% | Final Batch Error: 1.3780e-13
# Epoch 461/1000 | Avg Loss: 0.0198 | Accuracy: 99.84% | Final Batch Error: 1.3770e-13
# Epoch 462/1000 | Avg Loss: 0.0197 | Accuracy: 99.84% | Final Batch Error: 1.3803e-13
# Epoch 463/1000 | Avg Loss: 0.0196 | Accuracy: 99.84% | Final Batch Error: 1.3843e-13
# Epoch 464/1000 | Avg Loss: 0.0195 | Accuracy: 99.84% | Final Batch Error: 1.3879e-13
# Epoch 465/1000 | Avg Loss: 0.0197 | Accuracy: 99.85% | Final Batch Error: 1.3902e-13
# Epoch 466/1000 | Avg Loss: 0.0195 | Accuracy: 99.84% | Final Batch Error: 1.3927e-13
# Epoch 467/1000 | Avg Loss: 0.0198 | Accuracy: 99.84% | Final Batch Error: 1.3924e-13
# Epoch 468/1000 | Avg Loss: 0.0194 | Accuracy: 99.84% | Final Batch Error: 1.3933e-13
# Epoch 469/1000 | Avg Loss: 0.0193 | Accuracy: 99.84% | Final Batch Error: 1.3977e-13
# Epoch 470/1000 | Avg Loss: 0.0194 | Accuracy: 99.84% | Final Batch Error: 1.3977e-13
# Epoch 471/1000 | Avg Loss: 0.0192 | Accuracy: 99.84% | Final Batch Error: 1.4005e-13
# Epoch 472/1000 | Avg Loss: 0.0192 | Accuracy: 99.86% | Final Batch Error: 1.4033e-13
# Epoch 473/1000 | Avg Loss: 0.0191 | Accuracy: 99.84% | Final Batch Error: 1.4044e-13
# Epoch 474/1000 | Avg Loss: 0.0191 | Accuracy: 99.84% | Final Batch Error: 1.4092e-13
# Epoch 475/1000 | Avg Loss: 0.0191 | Accuracy: 99.85% | Final Batch Error: 1.4117e-13
# Epoch 476/1000 | Avg Loss: 0.0191 | Accuracy: 99.85% | Final Batch Error: 1.4162e-13
# Epoch 477/1000 | Avg Loss: 0.0191 | Accuracy: 99.86% | Final Batch Error: 1.4189e-13
# Epoch 478/1000 | Avg Loss: 0.0188 | Accuracy: 99.84% | Final Batch Error: 1.4216e-13
# Epoch 479/1000 | Avg Loss: 0.0188 | Accuracy: 99.86% | Final Batch Error: 1.4248e-13
# Epoch 480/1000 | Avg Loss: 0.0191 | Accuracy: 99.85% | Final Batch Error: 1.4271e-13
# Epoch 481/1000 | Avg Loss: 0.0187 | Accuracy: 99.85% | Final Batch Error: 1.4263e-13
# Epoch 482/1000 | Avg Loss: 0.0187 | Accuracy: 99.85% | Final Batch Error: 1.4247e-13
# Epoch 483/1000 | Avg Loss: 0.0186 | Accuracy: 99.86% | Final Batch Error: 1.4240e-13
# Epoch 484/1000 | Avg Loss: 0.0186 | Accuracy: 99.85% | Final Batch Error: 1.4268e-13
# Epoch 485/1000 | Avg Loss: 0.0185 | Accuracy: 99.86% | Final Batch Error: 1.4271e-13
# Epoch 486/1000 | Avg Loss: 0.0185 | Accuracy: 99.85% | Final Batch Error: 1.4284e-13
# Epoch 487/1000 | Avg Loss: 0.0184 | Accuracy: 99.85% | Final Batch Error: 1.4275e-13
# Epoch 488/1000 | Avg Loss: 0.0184 | Accuracy: 99.84% | Final Batch Error: 1.4277e-13
# Epoch 489/1000 | Avg Loss: 0.0183 | Accuracy: 99.84% | Final Batch Error: 1.4287e-13
# Epoch 490/1000 | Avg Loss: 0.0183 | Accuracy: 99.85% | Final Batch Error: 1.4312e-13
# Epoch 491/1000 | Avg Loss: 0.0183 | Accuracy: 99.87% | Final Batch Error: 1.4310e-13
# Epoch 492/1000 | Avg Loss: 0.0182 | Accuracy: 99.85% | Final Batch Error: 1.4319e-13
# Epoch 493/1000 | Avg Loss: 0.0182 | Accuracy: 99.85% | Final Batch Error: 1.4341e-13
# Epoch 494/1000 | Avg Loss: 0.0181 | Accuracy: 99.85% | Final Batch Error: 1.4346e-13
# Epoch 495/1000 | Avg Loss: 0.0181 | Accuracy: 99.86% | Final Batch Error: 1.4358e-13
# Epoch 496/1000 | Avg Loss: 0.0182 | Accuracy: 99.86% | Final Batch Error: 1.4373e-13
# Epoch 497/1000 | Avg Loss: 0.0180 | Accuracy: 99.85% | Final Batch Error: 1.4374e-13
# Epoch 498/1000 | Avg Loss: 0.0179 | Accuracy: 99.86% | Final Batch Error: 1.4401e-13
# Epoch 499/1000 | Avg Loss: 0.0179 | Accuracy: 99.86% | Final Batch Error: 1.4422e-13
# Epoch 500/1000 | Avg Loss: 0.0178 | Accuracy: 99.87% | Final Batch Error: 1.4424e-13
# Epoch 501/1000 | Avg Loss: 0.0179 | Accuracy: 99.87% | Final Batch Error: 1.4480e-13
# Epoch 502/1000 | Avg Loss: 0.0178 | Accuracy: 99.87% | Final Batch Error: 1.4485e-13
# Epoch 503/1000 | Avg Loss: 0.0178 | Accuracy: 99.88% | Final Batch Error: 1.4496e-13
# Epoch 504/1000 | Avg Loss: 0.0178 | Accuracy: 99.87% | Final Batch Error: 1.4506e-13
# Epoch 505/1000 | Avg Loss: 0.0178 | Accuracy: 99.87% | Final Batch Error: 1.4516e-13
# Epoch 506/1000 | Avg Loss: 0.0177 | Accuracy: 99.88% | Final Batch Error: 1.4526e-13
# Epoch 507/1000 | Avg Loss: 0.0175 | Accuracy: 99.86% | Final Batch Error: 1.4541e-13
# Epoch 508/1000 | Avg Loss: 0.0176 | Accuracy: 99.87% | Final Batch Error: 1.4578e-13
# Epoch 509/1000 | Avg Loss: 0.0177 | Accuracy: 99.88% | Final Batch Error: 1.4597e-13
# Epoch 510/1000 | Avg Loss: 0.0175 | Accuracy: 99.87% | Final Batch Error: 1.4614e-13
# Epoch 511/1000 | Avg Loss: 0.0174 | Accuracy: 99.87% | Final Batch Error: 1.4637e-13
# Epoch 512/1000 | Avg Loss: 0.0173 | Accuracy: 99.88% | Final Batch Error: 1.4660e-13
# Epoch 513/1000 | Avg Loss: 0.0173 | Accuracy: 99.88% | Final Batch Error: 1.4656e-13
# Epoch 514/1000 | Avg Loss: 0.0173 | Accuracy: 99.87% | Final Batch Error: 1.4663e-13
# Epoch 515/1000 | Avg Loss: 0.0172 | Accuracy: 99.87% | Final Batch Error: 1.4662e-13
# Epoch 516/1000 | Avg Loss: 0.0172 | Accuracy: 99.89% | Final Batch Error: 1.4677e-13
# Epoch 517/1000 | Avg Loss: 0.0172 | Accuracy: 99.87% | Final Batch Error: 1.4709e-13
# Epoch 518/1000 | Avg Loss: 0.0175 | Accuracy: 99.88% | Final Batch Error: 1.4748e-13
# Epoch 519/1000 | Avg Loss: 0.0171 | Accuracy: 99.87% | Final Batch Error: 1.4757e-13
# Epoch 520/1000 | Avg Loss: 0.0171 | Accuracy: 99.88% | Final Batch Error: 1.4790e-13
# Epoch 521/1000 | Avg Loss: 0.0170 | Accuracy: 99.89% | Final Batch Error: 1.4813e-13
# Epoch 522/1000 | Avg Loss: 0.0169 | Accuracy: 99.89% | Final Batch Error: 1.4813e-13
# Epoch 523/1000 | Avg Loss: 0.0169 | Accuracy: 99.88% | Final Batch Error: 1.4844e-13
# Epoch 524/1000 | Avg Loss: 0.0168 | Accuracy: 99.89% | Final Batch Error: 1.4844e-13
# Epoch 525/1000 | Avg Loss: 0.0171 | Accuracy: 99.88% | Final Batch Error: 1.4855e-13
# Epoch 526/1000 | Avg Loss: 0.0168 | Accuracy: 99.89% | Final Batch Error: 1.4868e-13
# Epoch 527/1000 | Avg Loss: 0.0168 | Accuracy: 99.90% | Final Batch Error: 1.4871e-13
# Epoch 528/1000 | Avg Loss: 0.0167 | Accuracy: 99.90% | Final Batch Error: 1.4886e-13
# Epoch 529/1000 | Avg Loss: 0.0166 | Accuracy: 99.89% | Final Batch Error: 1.4894e-13
# Epoch 530/1000 | Avg Loss: 0.0166 | Accuracy: 99.89% | Final Batch Error: 1.4911e-13
# Epoch 531/1000 | Avg Loss: 0.0166 | Accuracy: 99.89% | Final Batch Error: 1.4939e-13
# Epoch 532/1000 | Avg Loss: 0.0166 | Accuracy: 99.88% | Final Batch Error: 1.4961e-13
# Epoch 533/1000 | Avg Loss: 0.0165 | Accuracy: 99.90% | Final Batch Error: 1.4988e-13
# Epoch 534/1000 | Avg Loss: 0.0165 | Accuracy: 99.90% | Final Batch Error: 1.5017e-13
# Epoch 535/1000 | Avg Loss: 0.0164 | Accuracy: 99.90% | Final Batch Error: 1.5025e-13
# Epoch 536/1000 | Avg Loss: 0.0165 | Accuracy: 99.89% | Final Batch Error: 1.5036e-13
# Epoch 537/1000 | Avg Loss: 0.0163 | Accuracy: 99.90% | Final Batch Error: 1.5083e-13
# Epoch 538/1000 | Avg Loss: 0.0163 | Accuracy: 99.90% | Final Batch Error: 1.5093e-13
# Epoch 539/1000 | Avg Loss: 0.0163 | Accuracy: 99.90% | Final Batch Error: 1.5122e-13
# Epoch 540/1000 | Avg Loss: 0.0163 | Accuracy: 99.89% | Final Batch Error: 1.5138e-13
# Epoch 541/1000 | Avg Loss: 0.0162 | Accuracy: 99.90% | Final Batch Error: 1.5175e-13
# Epoch 542/1000 | Avg Loss: 0.0162 | Accuracy: 99.91% | Final Batch Error: 1.5219e-13
# Epoch 543/1000 | Avg Loss: 0.0161 | Accuracy: 99.90% | Final Batch Error: 1.5200e-13
# Epoch 544/1000 | Avg Loss: 0.0164 | Accuracy: 99.89% | Final Batch Error: 1.5197e-13
# Epoch 545/1000 | Avg Loss: 0.0161 | Accuracy: 99.90% | Final Batch Error: 1.5215e-13
# Epoch 546/1000 | Avg Loss: 0.0160 | Accuracy: 99.90% | Final Batch Error: 1.5255e-13
# Epoch 547/1000 | Avg Loss: 0.0160 | Accuracy: 99.90% | Final Batch Error: 1.5230e-13
# Epoch 548/1000 | Avg Loss: 0.0159 | Accuracy: 99.92% | Final Batch Error: 1.5253e-13
# Epoch 549/1000 | Avg Loss: 0.0160 | Accuracy: 99.90% | Final Batch Error: 1.5284e-13
# Epoch 550/1000 | Avg Loss: 0.0159 | Accuracy: 99.90% | Final Batch Error: 1.5305e-13
# Epoch 551/1000 | Avg Loss: 0.0160 | Accuracy: 99.89% | Final Batch Error: 1.5322e-13
# Epoch 552/1000 | Avg Loss: 0.0158 | Accuracy: 99.92% | Final Batch Error: 1.5341e-13
# Epoch 553/1000 | Avg Loss: 0.0158 | Accuracy: 99.92% | Final Batch Error: 1.5362e-13
# Epoch 554/1000 | Avg Loss: 0.0157 | Accuracy: 99.91% | Final Batch Error: 1.5370e-13
# Epoch 555/1000 | Avg Loss: 0.0157 | Accuracy: 99.92% | Final Batch Error: 1.5431e-13
# Epoch 556/1000 | Avg Loss: 0.0157 | Accuracy: 99.90% | Final Batch Error: 1.5447e-13
# Epoch 557/1000 | Avg Loss: 0.0156 | Accuracy: 99.92% | Final Batch Error: 1.5469e-13
# Epoch 558/1000 | Avg Loss: 0.0156 | Accuracy: 99.92% | Final Batch Error: 1.5493e-13
# Epoch 559/1000 | Avg Loss: 0.0155 | Accuracy: 99.92% | Final Batch Error: 1.5525e-13
# Epoch 560/1000 | Avg Loss: 0.0156 | Accuracy: 99.91% | Final Batch Error: 1.5556e-13
# Epoch 561/1000 | Avg Loss: 0.0155 | Accuracy: 99.91% | Final Batch Error: 1.5537e-13
# Epoch 562/1000 | Avg Loss: 0.0156 | Accuracy: 99.90% | Final Batch Error: 1.5545e-13
# Epoch 563/1000 | Avg Loss: 0.0154 | Accuracy: 99.92% | Final Batch Error: 1.5570e-13
# Epoch 564/1000 | Avg Loss: 0.0155 | Accuracy: 99.90% | Final Batch Error: 1.5593e-13
# Epoch 565/1000 | Avg Loss: 0.0154 | Accuracy: 99.92% | Final Batch Error: 1.5637e-13
# ...
# Epoch 817/1000 | Avg Loss: 0.0159 | Accuracy: 99.71% | Final Batch Error: 1.1178e-13
# Epoch 818/1000 | Avg Loss: 0.0159 | Accuracy: 99.74% | Final Batch Error: 1.1165e-13
# Epoch 819/1000 | Avg Loss: 0.0160 | Accuracy: 99.72% | Final Batch Error: 1.1234e-13
# Epoch 820/1000 | Avg Loss: 0.0159 | Accuracy: 99.74% | Final Batch Error: 1.1207e-13
# Epoch 821/1000 | Avg Loss: 0.0158 | Accuracy: 99.74% | Final Batch Error: 1.1206e-13
# Epoch 822/1000 | Avg Loss: 0.0159 | Accuracy: 99.72% | Final Batch Error: 1.1205e-13
# Epoch 823/1000 | Avg Loss: 0.0159 | Accuracy: 99.73% | Final Batch Error: 1.1247e-13
# Epoch 824/1000 | Avg Loss: 0.0158 | Accuracy: 99.74% | Final Batch Error: 1.1241e-13
# Epoch 825/1000 | Avg Loss: 0.0158 | Accuracy: 99.74% | Final Batch Error: 1.1327e-13
# Epoch 826/1000 | Avg Loss: 0.0158 | Accuracy: 99.72% | Final Batch Error: 1.1352e-13
# Epoch 827/1000 | Avg Loss: 0.0158 | Accuracy: 99.73% | Final Batch Error: 1.1325e-13
# Epoch 828/1000 | Avg Loss: 0.0157 | Accuracy: 99.72% | Final Batch Error: 1.1310e-13
# Epoch 829/1000 | Avg Loss: 0.0157 | Accuracy: 99.74% | Final Batch Error: 1.1327e-13
# Epoch 830/1000 | Avg Loss: 0.0157 | Accuracy: 99.74% | Final Batch Error: 1.1358e-13
# Epoch 831/1000 | Avg Loss: 0.0157 | Accuracy: 99.74% | Final Batch Error: 1.1386e-13
# Epoch 832/1000 | Avg Loss: 0.0158 | Accuracy: 99.74% | Final Batch Error: 1.1366e-13
# Epoch 833/1000 | Avg Loss: 0.0159 | Accuracy: 99.72% | Final Batch Error: 1.1335e-13
# Epoch 834/1000 | Avg Loss: 0.0157 | Accuracy: 99.73% | Final Batch Error: 1.1366e-13
# Epoch 835/1000 | Avg Loss: 0.0156 | Accuracy: 99.74% | Final Batch Error: 1.1398e-13
# Epoch 836/1000 | Avg Loss: 0.0156 | Accuracy: 99.73% | Final Batch Error: 1.1389e-13
# Epoch 837/1000 | Avg Loss: 0.0156 | Accuracy: 99.72% | Final Batch Error: 1.1416e-13
# Epoch 838/1000 | Avg Loss: 0.0156 | Accuracy: 99.73% | Final Batch Error: 1.1406e-13
# Epoch 839/1000 | Avg Loss: 0.0156 | Accuracy: 99.72% | Final Batch Error: 1.1386e-13
# Epoch 840/1000 | Avg Loss: 0.0156 | Accuracy: 99.76% | Final Batch Error: 1.1418e-13
# Epoch 841/1000 | Avg Loss: 0.0157 | Accuracy: 99.75% | Final Batch Error: 1.1372e-13
# Epoch 842/1000 | Avg Loss: 0.0156 | Accuracy: 99.75% | Final Batch Error: 1.1334e-13
# Epoch 843/1000 | Avg Loss: 0.0156 | Accuracy: 99.76% | Final Batch Error: 1.1331e-13
# Epoch 844/1000 | Avg Loss: 0.0155 | Accuracy: 99.75% | Final Batch Error: 1.1353e-13
# Epoch 845/1000 | Avg Loss: 0.0155 | Accuracy: 99.73% | Final Batch Error: 1.1339e-13
# Epoch 846/1000 | Avg Loss: 0.0158 | Accuracy: 99.75% | Final Batch Error: 1.1344e-13
# Epoch 847/1000 | Avg Loss: 0.0156 | Accuracy: 99.75% | Final Batch Error: 1.1355e-13
# Epoch 848/1000 | Avg Loss: 0.0155 | Accuracy: 99.74% | Final Batch Error: 1.1359e-13
# Epoch 849/1000 | Avg Loss: 0.0155 | Accuracy: 99.73% | Final Batch Error: 1.1417e-13
# Epoch 850/1000 | Avg Loss: 0.0154 | Accuracy: 99.73% | Final Batch Error: 1.1416e-13
# Epoch 851/1000 | Avg Loss: 0.0155 | Accuracy: 99.73% | Final Batch Error: 1.1446e-13
# Epoch 852/1000 | Avg Loss: 0.0155 | Accuracy: 99.74% | Final Batch Error: 1.1453e-13
# Epoch 853/1000 | Avg Loss: 0.0156 | Accuracy: 99.76% | Final Batch Error: 1.1432e-13
# Epoch 854/1000 | Avg Loss: 0.0154 | Accuracy: 99.75% | Final Batch Error: 1.1439e-13
# Epoch 855/1000 | Avg Loss: 0.0154 | Accuracy: 99.74% | Final Batch Error: 1.1479e-13
# Epoch 856/1000 | Avg Loss: 0.0153 | Accuracy: 99.75% | Final Batch Error: 1.1518e-13
# Epoch 857/1000 | Avg Loss: 0.0157 | Accuracy: 99.71% | Final Batch Error: 1.1452e-13
# Epoch 858/1000 | Avg Loss: 0.0153 | Accuracy: 99.75% | Final Batch Error: 1.1499e-13
# Epoch 859/1000 | Avg Loss: 0.0153 | Accuracy: 99.75% | Final Batch Error: 1.1501e-13
# Epoch 860/1000 | Avg Loss: 0.0153 | Accuracy: 99.74% | Final Batch Error: 1.1539e-13
# Epoch 861/1000 | Avg Loss: 0.0154 | Accuracy: 99.75% | Final Batch Error: 1.1522e-13
# Epoch 862/1000 | Avg Loss: 0.0152 | Accuracy: 99.75% | Final Batch Error: 1.1496e-13
# Epoch 863/1000 | Avg Loss: 0.0153 | Accuracy: 99.77% | Final Batch Error: 1.1482e-13
# Epoch 864/1000 | Avg Loss: 0.0153 | Accuracy: 99.74% | Final Batch Error: 1.1468e-13
# Epoch 865/1000 | Avg Loss: 0.0152 | Accuracy: 99.74% | Final Batch Error: 1.1475e-13
# Epoch 866/1000 | Avg Loss: 0.0154 | Accuracy: 99.76% | Final Batch Error: 1.1468e-13
# Epoch 867/1000 | Avg Loss: 0.0152 | Accuracy: 99.77% | Final Batch Error: 1.1449e-13
# Epoch 868/1000 | Avg Loss: 0.0152 | Accuracy: 99.75% | Final Batch Error: 1.1436e-13
# Epoch 869/1000 | Avg Loss: 0.0152 | Accuracy: 99.74% | Final Batch Error: 1.1451e-13
# Epoch 870/1000 | Avg Loss: 0.0151 | Accuracy: 99.74% | Final Batch Error: 1.1516e-13
# Epoch 871/1000 | Avg Loss: 0.0152 | Accuracy: 99.77% | Final Batch Error: 1.1501e-13
# Epoch 872/1000 | Avg Loss: 0.0151 | Accuracy: 99.75% | Final Batch Error: 1.1511e-13
# Epoch 873/1000 | Avg Loss: 0.0152 | Accuracy: 99.77% | Final Batch Error: 1.1509e-13
# Epoch 874/1000 | Avg Loss: 0.0152 | Accuracy: 99.77% | Final Batch Error: 1.1492e-13
# Epoch 875/1000 | Avg Loss: 0.0151 | Accuracy: 99.74% | Final Batch Error: 1.1546e-13
# Epoch 876/1000 | Avg Loss: 0.0151 | Accuracy: 99.77% | Final Batch Error: 1.1579e-13
# Epoch 877/1000 | Avg Loss: 0.0151 | Accuracy: 99.77% | Final Batch Error: 1.1585e-13
# Epoch 878/1000 | Avg Loss: 0.0150 | Accuracy: 99.74% | Final Batch Error: 1.1589e-13
# Epoch 879/1000 | Avg Loss: 0.0152 | Accuracy: 99.75% | Final Batch Error: 1.1637e-13
# Epoch 880/1000 | Avg Loss: 0.0150 | Accuracy: 99.75% | Final Batch Error: 1.1628e-13
# Epoch 881/1000 | Avg Loss: 0.0150 | Accuracy: 99.75% | Final Batch Error: 1.1693e-13
# Epoch 882/1000 | Avg Loss: 0.0150 | Accuracy: 99.74% | Final Batch Error: 1.1749e-13
# Epoch 883/1000 | Avg Loss: 0.0151 | Accuracy: 99.75% | Final Batch Error: 1.1745e-13
# Epoch 884/1000 | Avg Loss: 0.0149 | Accuracy: 99.74% | Final Batch Error: 1.1739e-13
# Epoch 885/1000 | Avg Loss: 0.0149 | Accuracy: 99.75% | Final Batch Error: 1.1792e-13
# Epoch 886/1000 | Avg Loss: 0.0149 | Accuracy: 99.76% | Final Batch Error: 1.1832e-13
# Epoch 887/1000 | Avg Loss: 0.0150 | Accuracy: 99.76% | Final Batch Error: 1.1766e-13
# Epoch 888/1000 | Avg Loss: 0.0149 | Accuracy: 99.74% | Final Batch Error: 1.1776e-13
# Epoch 889/1000 | Avg Loss: 0.0149 | Accuracy: 99.76% | Final Batch Error: 1.1782e-13
# Epoch 890/1000 | Avg Loss: 0.0149 | Accuracy: 99.76% | Final Batch Error: 1.1838e-13
# Epoch 891/1000 | Avg Loss: 0.0149 | Accuracy: 99.75% | Final Batch Error: 1.1840e-13
# Epoch 892/1000 | Avg Loss: 0.0148 | Accuracy: 99.75% | Final Batch Error: 1.1890e-13
# Epoch 893/1000 | Avg Loss: 0.0148 | Accuracy: 99.76% | Final Batch Error: 1.1938e-13
# Epoch 894/1000 | Avg Loss: 0.0149 | Accuracy: 99.76% | Final Batch Error: 1.1938e-13
# Epoch 895/1000 | Avg Loss: 0.0148 | Accuracy: 99.76% | Final Batch Error: 1.1955e-13
# Epoch 896/1000 | Avg Loss: 0.0150 | Accuracy: 99.75% | Final Batch Error: 1.1970e-13
# Epoch 897/1000 | Avg Loss: 0.0149 | Accuracy: 99.77% | Final Batch Error: 1.1962e-13
# Epoch 898/1000 | Avg Loss: 0.0148 | Accuracy: 99.77% | Final Batch Error: 1.1976e-13
# Epoch 899/1000 | Avg Loss: 0.0148 | Accuracy: 99.76% | Final Batch Error: 1.1965e-13
# Epoch 900/1000 | Avg Loss: 0.0148 | Accuracy: 99.76% | Final Batch Error: 1.1944e-13
# Epoch 901/1000 | Avg Loss: 0.0147 | Accuracy: 99.76% | Final Batch Error: 1.1950e-13
# Epoch 902/1000 | Avg Loss: 0.0148 | Accuracy: 99.76% | Final Batch Error: 1.1907e-13
# Epoch 903/1000 | Avg Loss: 0.0148 | Accuracy: 99.76% | Final Batch Error: 1.1954e-13
# Epoch 904/1000 | Avg Loss: 0.0147 | Accuracy: 99.76% | Final Batch Error: 1.1935e-13
# Epoch 905/1000 | Avg Loss: 0.0147 | Accuracy: 99.76% | Final Batch Error: 1.1910e-13
# Epoch 906/1000 | Avg Loss: 0.0147 | Accuracy: 99.76% | Final Batch Error: 1.1870e-13
# Epoch 907/1000 | Avg Loss: 0.0147 | Accuracy: 99.77% | Final Batch Error: 1.1845e-13
# Epoch 908/1000 | Avg Loss: 0.0146 | Accuracy: 99.77% | Final Batch Error: 1.1859e-13
# Epoch 909/1000 | Avg Loss: 0.0147 | Accuracy: 99.77% | Final Batch Error: 1.1842e-13
# Epoch 910/1000 | Avg Loss: 0.0146 | Accuracy: 99.77% | Final Batch Error: 1.1807e-13
# Epoch 911/1000 | Avg Loss: 0.0147 | Accuracy: 99.76% | Final Batch Error: 1.1814e-13
# Epoch 912/1000 | Avg Loss: 0.0146 | Accuracy: 99.77% | Final Batch Error: 1.1793e-13
# Epoch 913/1000 | Avg Loss: 0.0147 | Accuracy: 99.75% | Final Batch Error: 1.1856e-13
# Epoch 914/1000 | Avg Loss: 0.0146 | Accuracy: 99.77% | Final Batch Error: 1.1857e-13
# Epoch 915/1000 | Avg Loss: 0.0146 | Accuracy: 99.76% | Final Batch Error: 1.1806e-13
# Epoch 916/1000 | Avg Loss: 0.0145 | Accuracy: 99.77% | Final Batch Error: 1.1787e-13
# Epoch 917/1000 | Avg Loss: 0.0146 | Accuracy: 99.76% | Final Batch Error: 1.1796e-13
# Epoch 918/1000 | Avg Loss: 0.0147 | Accuracy: 99.75% | Final Batch Error: 1.1854e-13
# Epoch 919/1000 | Avg Loss: 0.0145 | Accuracy: 99.77% | Final Batch Error: 1.1878e-13
# Epoch 920/1000 | Avg Loss: 0.0145 | Accuracy: 99.77% | Final Batch Error: 1.1860e-13
# Epoch 921/1000 | Avg Loss: 0.0145 | Accuracy: 99.76% | Final Batch Error: 1.1887e-13
# Epoch 922/1000 | Avg Loss: 0.0145 | Accuracy: 99.77% | Final Batch Error: 1.1912e-13
# Epoch 923/1000 | Avg Loss: 0.0145 | Accuracy: 99.76% | Final Batch Error: 1.1929e-13
# Epoch 924/1000 | Avg Loss: 0.0144 | Accuracy: 99.76% | Final Batch Error: 1.1979e-13
# Epoch 925/1000 | Avg Loss: 0.0146 | Accuracy: 99.75% | Final Batch Error: 1.1959e-13
# Epoch 926/1000 | Avg Loss: 0.0144 | Accuracy: 99.77% | Final Batch Error: 1.1961e-13
# Epoch 927/1000 | Avg Loss: 0.0144 | Accuracy: 99.77% | Final Batch Error: 1.1945e-13
# Epoch 928/1000 | Avg Loss: 0.0144 | Accuracy: 99.77% | Final Batch Error: 1.1971e-13
# Epoch 929/1000 | Avg Loss: 0.0144 | Accuracy: 99.77% | Final Batch Error: 1.1981e-13
# Epoch 930/1000 | Avg Loss: 0.0144 | Accuracy: 99.77% | Final Batch Error: 1.2015e-13
# Epoch 931/1000 | Avg Loss: 0.0144 | Accuracy: 99.77% | Final Batch Error: 1.2066e-13
# Epoch 932/1000 | Avg Loss: 0.0143 | Accuracy: 99.78% | Final Batch Error: 1.2096e-13
# Epoch 933/1000 | Avg Loss: 0.0144 | Accuracy: 99.77% | Final Batch Error: 1.2164e-13
# Epoch 934/1000 | Avg Loss: 0.0143 | Accuracy: 99.77% | Final Batch Error: 1.2149e-13
# Epoch 935/1000 | Avg Loss: 0.0143 | Accuracy: 99.77% | Final Batch Error: 1.2125e-13
# Epoch 936/1000 | Avg Loss: 0.0143 | Accuracy: 99.77% | Final Batch Error: 1.2151e-13
# Epoch 937/1000 | Avg Loss: 0.0144 | Accuracy: 99.77% | Final Batch Error: 1.2206e-13
# Epoch 938/1000 | Avg Loss: 0.0143 | Accuracy: 99.77% | Final Batch Error: 1.2193e-13
# Epoch 939/1000 | Avg Loss: 0.0143 | Accuracy: 99.77% | Final Batch Error: 1.2193e-13
# Epoch 940/1000 | Avg Loss: 0.0144 | Accuracy: 99.76% | Final Batch Error: 1.2219e-13
# Epoch 941/1000 | Avg Loss: 0.0142 | Accuracy: 99.77% | Final Batch Error: 1.2270e-13
# Epoch 942/1000 | Avg Loss: 0.0143 | Accuracy: 99.77% | Final Batch Error: 1.2281e-13
# Epoch 943/1000 | Avg Loss: 0.0142 | Accuracy: 99.77% | Final Batch Error: 1.2250e-13
# Epoch 944/1000 | Avg Loss: 0.0142 | Accuracy: 99.77% | Final Batch Error: 1.2295e-13
# Epoch 945/1000 | Avg Loss: 0.0142 | Accuracy: 99.77% | Final Batch Error: 1.2304e-13
# Epoch 946/1000 | Avg Loss: 0.0142 | Accuracy: 99.77% | Final Batch Error: 1.2325e-13
# Epoch 947/1000 | Avg Loss: 0.0143 | Accuracy: 99.75% | Final Batch Error: 1.2291e-13
# Epoch 948/1000 | Avg Loss: 0.0142 | Accuracy: 99.77% | Final Batch Error: 1.2277e-13
# Epoch 949/1000 | Avg Loss: 0.0141 | Accuracy: 99.77% | Final Batch Error: 1.2303e-13
# Epoch 950/1000 | Avg Loss: 0.0142 | Accuracy: 99.77% | Final Batch Error: 1.2320e-13
# Epoch 951/1000 | Avg Loss: 0.0142 | Accuracy: 99.77% | Final Batch Error: 1.2351e-13
# Epoch 952/1000 | Avg Loss: 0.0141 | Accuracy: 99.77% | Final Batch Error: 1.2354e-13
# Epoch 953/1000 | Avg Loss: 0.0141 | Accuracy: 99.77% | Final Batch Error: 1.2386e-13
# Epoch 954/1000 | Avg Loss: 0.0141 | Accuracy: 99.78% | Final Batch Error: 1.2342e-13
# Epoch 955/1000 | Avg Loss: 0.0141 | Accuracy: 99.78% | Final Batch Error: 1.2347e-13
# Epoch 956/1000 | Avg Loss: 0.0141 | Accuracy: 99.79% | Final Batch Error: 1.2427e-13
# Epoch 957/1000 | Avg Loss: 0.0140 | Accuracy: 99.78% | Final Batch Error: 1.2428e-13
# Epoch 958/1000 | Avg Loss: 0.0140 | Accuracy: 99.77% | Final Batch Error: 1.2439e-13
# Epoch 959/1000 | Avg Loss: 0.0140 | Accuracy: 99.77% | Final Batch Error: 1.2437e-13
# Epoch 960/1000 | Avg Loss: 0.0140 | Accuracy: 99.78% | Final Batch Error: 1.2433e-13
# Epoch 961/1000 | Avg Loss: 0.0140 | Accuracy: 99.78% | Final Batch Error: 1.2453e-13
# Epoch 962/1000 | Avg Loss: 0.0140 | Accuracy: 99.78% | Final Batch Error: 1.2462e-13
# Epoch 963/1000 | Avg Loss: 0.0140 | Accuracy: 99.78% | Final Batch Error: 1.2459e-13
# Epoch 964/1000 | Avg Loss: 0.0140 | Accuracy: 99.77% | Final Batch Error: 1.2455e-13
# Epoch 965/1000 | Avg Loss: 0.0140 | Accuracy: 99.77% | Final Batch Error: 1.2460e-13
# Epoch 966/1000 | Avg Loss: 0.0140 | Accuracy: 99.77% | Final Batch Error: 1.2443e-13
# Epoch 967/1000 | Avg Loss: 0.0141 | Accuracy: 99.77% | Final Batch Error: 1.2467e-13
# Epoch 968/1000 | Avg Loss: 0.0139 | Accuracy: 99.78% | Final Batch Error: 1.2527e-13
# Epoch 969/1000 | Avg Loss: 0.0140 | Accuracy: 99.77% | Final Batch Error: 1.2552e-13
# Epoch 970/1000 | Avg Loss: 0.0139 | Accuracy: 99.78% | Final Batch Error: 1.2569e-13
# Epoch 971/1000 | Avg Loss: 0.0140 | Accuracy: 99.77% | Final Batch Error: 1.2580e-13
# Epoch 972/1000 | Avg Loss: 0.0139 | Accuracy: 99.78% | Final Batch Error: 1.2537e-13
# Epoch 973/1000 | Avg Loss: 0.0139 | Accuracy: 99.77% | Final Batch Error: 1.2547e-13
# Epoch 974/1000 | Avg Loss: 0.0138 | Accuracy: 99.78% | Final Batch Error: 1.2540e-13
# Epoch 975/1000 | Avg Loss: 0.0139 | Accuracy: 99.77% | Final Batch Error: 1.2561e-13
# Epoch 976/1000 | Avg Loss: 0.0138 | Accuracy: 99.79% | Final Batch Error: 1.2572e-13
# Epoch 977/1000 | Avg Loss: 0.0140 | Accuracy: 99.77% | Final Batch Error: 1.2644e-13
# Epoch 978/1000 | Avg Loss: 0.0138 | Accuracy: 99.77% | Final Batch Error: 1.2666e-13
# Epoch 979/1000 | Avg Loss: 0.0138 | Accuracy: 99.79% | Final Batch Error: 1.2668e-13
# Epoch 980/1000 | Avg Loss: 0.0138 | Accuracy: 99.79% | Final Batch Error: 1.2666e-13
# Epoch 981/1000 | Avg Loss: 0.0139 | Accuracy: 99.77% | Final Batch Error: 1.2685e-13
# Epoch 982/1000 | Avg Loss: 0.0138 | Accuracy: 99.77% | Final Batch Error: 1.2700e-13
# Epoch 983/1000 | Avg Loss: 0.0137 | Accuracy: 99.78% | Final Batch Error: 1.2708e-13
# Epoch 984/1000 | Avg Loss: 0.0138 | Accuracy: 99.77% | Final Batch Error: 1.2694e-13
# Epoch 985/1000 | Avg Loss: 0.0138 | Accuracy: 99.77% | Final Batch Error: 1.2736e-13
# Epoch 986/1000 | Avg Loss: 0.0139 | Accuracy: 99.79% | Final Batch Error: 1.2723e-13
# Epoch 987/1000 | Avg Loss: 0.0138 | Accuracy: 99.77% | Final Batch Error: 1.2682e-13
# Epoch 988/1000 | Avg Loss: 0.0137 | Accuracy: 99.79% | Final Batch Error: 1.2696e-13
# Epoch 989/1000 | Avg Loss: 0.0137 | Accuracy: 99.79% | Final Batch Error: 1.2743e-13
# Epoch 990/1000 | Avg Loss: 0.0137 | Accuracy: 99.77% | Final Batch Error: 1.2798e-13
# Epoch 991/1000 | Avg Loss: 0.0137 | Accuracy: 99.78% | Final Batch Error: 1.2775e-13
# Epoch 992/1000 | Avg Loss: 0.0137 | Accuracy: 99.77% | Final Batch Error: 1.2746e-13
# Epoch 993/1000 | Avg Loss: 0.0137 | Accuracy: 99.78% | Final Batch Error: 1.2774e-13
# Epoch 994/1000 | Avg Loss: 0.0136 | Accuracy: 99.78% | Final Batch Error: 1.2793e-13
# Epoch 995/1000 | Avg Loss: 0.0136 | Accuracy: 99.79% | Final Batch Error: 1.2781e-13
# Epoch 996/1000 | Avg Loss: 0.0137 | Accuracy: 99.78% | Final Batch Error: 1.2815e-13
# Epoch 997/1000 | Avg Loss: 0.0136 | Accuracy: 99.78% | Final Batch Error: 1.2782e-13
# Epoch 998/1000 | Avg Loss: 0.0136 | Accuracy: 99.79% | Final Batch Error: 1.2809e-13
# Epoch 999/1000 | Avg Loss: 0.0137 | Accuracy: 99.77% | Final Batch Error: 1.2815e-13
# Epoch 1000/1000 | Avg Loss: 0.0136 | Accuracy: 99.79% | Final Batch Error: 1.2814e-13
# Result: Max Trajectory Error = 1.2839e-13
# --------------------------------------------------
#
# ========= MNIST Experiment Summary =========
# mlp_no_bias    : Max Trajectory Error = 2.1868e-13
# cnn_no_bias    : Max Trajectory Error = 1.2839e-13
# ==========================================
